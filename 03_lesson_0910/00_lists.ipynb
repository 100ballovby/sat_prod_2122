# %% [markdown]
# # Списки
#
# <p>Список - это <b>индексируемая</b> последовательность элементов, заключенная в квадратные скобки. Каждый элемент разделается запятой.</p>

# %%
my_list = [23, 56, 12, 89, 101]

print(type(my_list))
# Out:
# <class 'list'>

# %% [markdown]
# <p>Если я хочу получить из списка какое-то значение, я обращаюсь по индексу элемента, который хочу получить. <code>list_name[index]</code></p>

# %%
print(my_list[4])
# Out:
# 101

# %% [markdown]
# ## Методы списков
#
# <p>1. <code>.append(x)</code> - метод добавляет внутрь списка <code>x</code>.</p>

# %%
print(my_list)

my_list.append([567, 56, 7, 3, 2])

print(my_list)
# Out:
# [23, 56, 12, 89, 101, 567]
# [23, 56, 12, 89, 101, 567, [567, 56, 7, 3, 2]]

# %% [markdown]
# <p>2. <code>.pop(index)</code> - метод удаляет из списка <code>index</code> ИЛИ <code>.pop()</code> последний элемент, если индекс не указан.</p>

# %%
my_list.pop()
print(my_list)
# Out:
# [23, 56, 12, 89, 101, 567]

# %% [markdown]
# <p>2. <code>.sort()</code> - сортирует список по возрастанию.</p>

# %%
my_list.sort()

print(my_list)
# Out:
# [12, 23, 56, 89, 101, 567]

# %% [markdown]
# ## Замена элемента в списке
#
# <p>Список - изменяемая коллекция данных.</p>

# %%
my_list[1] = 'Привет!'

print(my_list)
# Out:
# [12, 'Привет!', 56, 89, 101, 567]

# %% [markdown]
# ## Библиотеки
#
# <p><b>Импортировать библиотеку</b> - добавить переменные, фукнции и классы, входящие в библиотеку внутрь вашего проекта.</p>
# <p><b>Библиотека</b> - это набор модулей, которые вы можете применить для улучшения своей программы.</p>
#
# <p>Виды импортов:</p>
#
# <ol>
#     <li><code>import <em>&lt;library name&gt;</em></code> - это означает "подключить библиотеку". При таком способе импорта, вам нужно будет всегда прописывать имя библиотеки перед названием функции из этой библиотеки: <code><em>&lt;library name&gt;</em>.function()</code></li>
#     <li><b>Самый желательный!</b> <code>import <em>&lt;library name&gt;</em> as &lt;alias&gt;</code>. При таком способе импорта, вам нужно будет всегда прописывать сокращение имени библиотеки перед названием функции из этой библиотеки: <code><em>&lt;alias&gt;</em>.function()</code></li>
#     <li><code>from <em>&lt;library name&gt;</em> import function1, function2</code>. При таком способе импорта нет необходимости прописывать имя библиотеки, потому что вы импортируете отдельные функции из нее. Но вы можете столкнуться с конфликтом имен. Если функция в вашей программе будет совпадать с названием функции библиотеки. Способ обращения к функции из библиотеки выглядит так: <code>function1()</code></li>
#     <li><b>Самый нежелательный!</b> <code>from <em>&lt;library name&gt;</em> import *</code> - импортировать ВСË из библиотеки. Данный вид импорта гарантирует вам конфликт имен, если вдруг вы решите написать свои функции. Способ обращения к функции из библиотеки выглядит так: <code>function_n()</code></li>
# </ol>
#
# <hr>
#
# ## Наполнение списка

# %%
import random as r

l = []  # его надо наполнить 

for i in range(10):
    l.append(r.randint(-100, 100))
    
print(l)
# Out:
# [12, 2, 25, -43, 100, 67, 42, -31, -100, -99]

# %% [markdown]
# ## Способ 2. Генератор

# %%
l2 = [r.randint(-100, 100) for i in range(10)]

print(l2)
# Out:
# [20, 89, -53, -84, -63, 25, 45, -12, -83, -67]

# %% [markdown]
# ## Задача: наполнить список числами в диапазоне от 2000 до 4600, которые делятся на 3 и на 5

# %%
l3 = []

for k in range(2000, 4601):
    if k % 15 == 0:
        l3.append(k)
    
print(l3)
# Out:
# [2010, 2025, 2040, 2055, 2070, 2085, 2100, 2115, 2130, 2145, 2160, 2175, 2190, 2205, 2220, 2235, 2250, 2265, 2280, 2295, 2310, 2325, 2340, 2355, 2370, 2385, 2400, 2415, 2430, 2445, 2460, 2475, 2490, 2505, 2520, 2535, 2550, 2565, 2580, 2595, 2610, 2625, 2640, 2655, 2670, 2685, 2700, 2715, 2730, 2745, 2760, 2775, 2790, 2805, 2820, 2835, 2850, 2865, 2880, 2895, 2910, 2925, 2940, 2955, 2970, 2985, 3000, 3015, 3030, 3045, 3060, 3075, 3090, 3105, 3120, 3135, 3150, 3165, 3180, 3195, 3210, 3225, 3240, 3255, 3270, 3285, 3300, 3315, 3330, 3345, 3360, 3375, 3390, 3405, 3420, 3435, 3450, 3465, 3480, 3495, 3510, 3525, 3540, 3555, 3570, 3585, 3600, 3615, 3630, 3645, 3660, 3675, 3690, 3705, 3720, 3735, 3750, 3765, 3780, 3795, 3810, 3825, 3840, 3855, 3870, 3885, 3900, 3915, 3930, 3945, 3960, 3975, 3990, 4005, 4020, 4035, 4050, 4065, 4080, 4095, 4110, 4125, 4140, 4155, 4170, 4185, 4200, 4215, 4230, 4245, 4260, 4275, 4290, 4305, 4320, 4335, 4350, 4365, 4380, 4395, 4410, 4425, 4440, 4455, 4470, 4485, 4500, 4515, 4530, 4545, 4560, 4575, 4590]

# %% [markdown]
# ## Способ 2. Через генератор

# %%
l4 = [i for i in range(2000, 4601) if i % 15 == 0]

print(l4)
# Out:
# [2010, 2025, 2040, 2055, 2070, 2085, 2100, 2115, 2130, 2145, 2160, 2175, 2190, 2205, 2220, 2235, 2250, 2265, 2280, 2295, 2310, 2325, 2340, 2355, 2370, 2385, 2400, 2415, 2430, 2445, 2460, 2475, 2490, 2505, 2520, 2535, 2550, 2565, 2580, 2595, 2610, 2625, 2640, 2655, 2670, 2685, 2700, 2715, 2730, 2745, 2760, 2775, 2790, 2805, 2820, 2835, 2850, 2865, 2880, 2895, 2910, 2925, 2940, 2955, 2970, 2985, 3000, 3015, 3030, 3045, 3060, 3075, 3090, 3105, 3120, 3135, 3150, 3165, 3180, 3195, 3210, 3225, 3240, 3255, 3270, 3285, 3300, 3315, 3330, 3345, 3360, 3375, 3390, 3405, 3420, 3435, 3450, 3465, 3480, 3495, 3510, 3525, 3540, 3555, 3570, 3585, 3600, 3615, 3630, 3645, 3660, 3675, 3690, 3705, 3720, 3735, 3750, 3765, 3780, 3795, 3810, 3825, 3840, 3855, 3870, 3885, 3900, 3915, 3930, 3945, 3960, 3975, 3990, 4005, 4020, 4035, 4050, 4065, 4080, 4095, 4110, 4125, 4140, 4155, 4170, 4185, 4200, 4215, 4230, 4245, 4260, 4275, 4290, 4305, 4320, 4335, 4350, 4365, 4380, 4395, 4410, 4425, 4440, 4455, 4470, 4485, 4500, 4515, 4530, 4545, 4560, 4575, 4590]
